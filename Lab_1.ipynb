# %% [markdown]
# # Lab 1: The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# ## Define and Compile the Neural Network

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# 2025-03-24 14:13:45.242613: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.5799
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5675
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5555
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5437
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5323
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5212
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5104
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4998
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4894
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4793
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4694
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4597
# ...

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 78ms/step
# [[18.9875]]

# %% [markdown]
# Model was trained on a limited dataset, so it made an approximate prediction rather than the exact value of 19.
#
# ### Why is the prediction slightly lower than 19?
#
# #### Limited training data
#
# - The model was trained on only six data points, which doesn’t guarantee perfect generalization.
#
# #### Error (Loss) and Optimization
#
# - Even after training, the model may not produce an exact result due to a small optimization error.
#
# #### The probabilistic nature of predictions
#
# - Neural networks don’t provide exact values but rather estimate probabilistic relationships.
# - Even if the relationship seems simple (y = 2x - 1), the neural network only finds the best approximation.
#
# ### How to improve accuracy?
# ✅ Add more training data
#
# ✅ Train for more epochs
#
# ✅ Check the activation function and model architecture
#
# ✅ Reduce the learning rate if predictions are unstable
